# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana1/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a1 = 0
a2 = 1
a3 = 3
# = operador -> ASIGNACION
type(a)
# Out:
# int

# %%
# Si necesitamos manejar mas de un valor, necesitamos una estructura de datos
lista1 = [1,2,3]
type(lista1)
# Out:
# list

# %%
b = [2,4,5,6]
type(b)
# Out:
# list
