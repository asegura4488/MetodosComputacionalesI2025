# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana4/Interpolacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %%
X = np.array([-2,-0.5,0,1])
Y = np.array([-1,3,0,2])

# %%
plt.scatter(X,Y)

# %%
# Queremos crear las bases cardinales sobre el soporte
def Lagrange(x,X,i):

  L = 1
  for j in range(len(X)):
    if i != j:
      L *= (x - X[j])/(X[i]-X[j])

  return L

# %%
x = sym.Symbol('x',real=True)
Lagrange(x,X,0)
# Out:
# -0.5*x*(0.333333333333333 - 0.333333333333333*x)*(-0.666666666666667*x - 0.333333333333333)

# %%
Lagrange(x,X,1).simplify()
# Out:
# 1.33333333333333*x*(0.666666666666667*x + 1.33333333333333)*(x - 1)

# %%
Lagrange(x,X,0).subs(x,X[0])
# Out:
# 1.00000000000000

# %%
Lagrange(x,X,1).subs(x,X[2])
# Out:
# 0

# %%
def Interpolate(x,X,Y):

  Poly = 0
  for i in range(len(X)):
    Poly += Y[i]*Lagrange(x,X,i)

  return Poly

# %%
Interpolate(x,X,Y).simplify()
# Out:
# x*(3.22222222222222*x**2 + 3.72222222222222*x - 4.94444444444444)

# %%
plt.scatter(X,Y,color='r')
x1 = np.linspace(X[0],X[-1],50)
print(x1)
y1 = Interpolate(x1,X,Y)
plt.plot(x1,y1)
# Out:
# [-2.         -1.93877551 -1.87755102 -1.81632653 -1.75510204 -1.69387755
#  -1.63265306 -1.57142857 -1.51020408 -1.44897959 -1.3877551  -1.32653061
#  -1.26530612 -1.20408163 -1.14285714 -1.08163265 -1.02040816 -0.95918367
#  -0.89795918 -0.83673469 -0.7755102  -0.71428571 -0.65306122 -0.59183673
#  -0.53061224 -0.46938776 -0.40816327 -0.34693878 -0.28571429 -0.2244898
#  -0.16326531 -0.10204082 -0.04081633  0.02040816  0.08163265  0.14285714
#   0.20408163  0.26530612  0.32653061  0.3877551   0.44897959  0.51020408
#   0.57142857  0.63265306  0.69387755  0.75510204  0.81632653  0.87755102
#   0.93877551  1.        ]

# %%
poly = Interpolate(x,X,Y).simplify()
poly.subs(x,-0.25)
# Out:
# 1.41840277777778
