# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana4/DerivadaDireccional1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def f2(x,y):
  return x**4 + y**4 - 2*(x-y)**2

# %%
x = np.linspace(-2,2,60)
y = np.linspace(-2,2,60)
X,Y = np.meshgrid(x,y)

# %%
# Necesitamos las derivadas parciales
Dx = lambda x,y,h=1e-5: (f2(x+h,y)-f2(x-h,y))/(2*h)
Dy = lambda x,y,h=1e-5: (f2(x,y+h)-f2(x,y-h))/(2*h)

# %%
Dx(0.2,0.3)
# Out:
# 0.4320000000804409

# %%
Dy(0.2,0.3)
# Out:
# -0.2919999998803047

# %%
plt.scatter(X,Y)

# %%
fig = plt.figure()
ax = fig.add_subplot( projection='3d')
ax.plot_surface(X,Y,f2(X,Y))
