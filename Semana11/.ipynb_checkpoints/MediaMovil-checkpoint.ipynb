# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana11/MediaMovil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import os
os.chdir('/content/drive/MyDrive/ColabNotebooks/Cursos/MetodosComputacionalesI2025/Semana11')
# !ls
# Out:
# Data  MediaMovil.ipynb

# %%
# !pwd
# Out:
# /home/ma.segura10/Codes/MetodosComputacionalesI2025/Semana11

# %%
data = pd.read_csv('Data/trialcurvesRXJ1131.txt', sep='\t')
#data = pd.read_csv('Data/trialcurvesQ2237.txt', sep='\t')
data
# Out:
#                t        M1   Error1        M2   Error2        M3   Error3  \
# 0    52988.31255 -12.83561  0.00710 -12.89500  0.00777 -11.78404  0.00933
# 1    52995.30600 -12.80570  0.00473 -12.86418  0.00466 -11.76767  0.00723
# 2    53002.32091 -12.79833  0.00705 -12.83406  0.00379 -11.73317  0.00932
# 3    53013.32044 -12.77932  0.00483 -12.75148  0.00489 -11.68157  0.01482
# 4    53021.29184 -12.75228  0.00581 -12.75571  0.00581 -11.74885  0.02114
# ..           ...       ...      ...       ...      ...       ...      ...
# 917  58298.01686 -12.75301  0.00586 -11.91142  0.00615 -10.95274  0.03222
# 918  58310.99133 -13.06515  0.00639 -12.09823  0.03000 -11.16013  0.02996
# 919  58313.98144 -13.09377  0.00288 -12.14034  0.00719 -11.22022  0.00581
# 920  58319.97229 -13.11349  0.01028 -12.20059  0.01626 -11.05070  0.02812
# 921  58320.96730 -13.13287  0.00268 -12.12117  0.02414 -11.24789  0.02630
#
#            M4   Error4
# 0   -10.43047  0.03145
# 1   -10.42736  0.02184
# 2   -10.45533  0.01647
# 3   -10.29250  0.04443
# 4   -10.43770  0.02205
# ..        ...      ...
# 917  -9.25584  0.11940
# 918  -9.29282  0.02964
# 919  -9.37810  0.02384
# 920  -9.64291  0.06512
# 921  -9.40720  0.04704
#
# [922 rows x 9 columns]

# %%
# COntexto: ventas en dolares de un almacen durando 18 dias
# Tarea: Elaborar un modelo que prediga la venta en el día 19
# Modelo: Definimos un modelo: Alejandro dice "sencillo - regresion"
import matplotlib.pyplot as plt
import numpy as np
x = np.array((data.M1[:]))
plt.plot(x)

# %%
# estudiante de primer semestre
mean = np.mean(x)
plt.plot(x)
plt.axhline(y=mean, color='r', linestyle='-')

# %%
# Queremos constriuir una media movil
def GetMediaMovil(x,n):

  media = np.zeros((len(x)+1)) # Incluyo la prediccion

  for i in range(len(media)):

    sum_ = 0.

    if i > n:

      for j in range(i-n,i):

        sum_ += x[j]

      media[i] = sum_/n

    else:
      media[i] = x[i]

  return media

# %%
media = GetMediaMovil(x,3)

# %%
plt.plot(x)
plt.plot(media,label='media movil standard')

# %%
media[-1]
# Out:
# -13.113376666666667

# %%
# Media movil ponderada
# El vector de ponderacion
# SI metos 0.75,0.25
def GetMediaMovilPonderada(x,w):

  n = len(w)
  media = np.zeros((len(x)+1))

  for i in range(len(media)):

    sum_ = 0.

    if i >= n:

      k = 0
      for j in range(i-n,i):

        sum_ += w[k]*x[j]

        k += 1

      media[i] = sum_

    else:
      media[i] = x[i]

  return media

# %%
w = np.array([0.3,0.2,0.5])
Wmedia = GetMediaMovilPonderada(x,w)
plt.plot(x)
plt.plot(media,label='media movil standard')
plt.plot(Wmedia,label='media movil ponderada')
plt.legend()

# %%
# Necesitamos una metrica de rendimiento:
# Valor cuadratico media
# Valor absoluto media
# Entropia cruzada

# %%
def GetRSS(x,y):
  # Ahora implementando AIC
  RSS = np.sum((x-y)**2)
  return RSS

# %%
GetRSS(x,Wmedia[:-1])
# Out:
# 4.447316385383001

# %%
def restriccion(w):
  return np.sum(w) - 1

# %%
import scipy.optimize as sp

# %%
def Cost(w):


  Wmedia = GetMediaMovilPonderada(x,w)
  RSS = GetRSS(x,Wmedia[:-1])
  n = len(x)
  k = w.shape[0]

  AIC = n*np.log(RSS/n) + 2.*k


  # Correccion para pequeñas muestras
  k_eff = k - 1  # Grados de libertad por la restricción
  n_eff = len(x) - k_eff # Grades de libertad estadísticos
  AICc = AIC + (2*k_eff*(k_eff+1)) / max(1, (n_eff - k_eff - 1))

  return AICc

# %%
w0 = np.array([0.5,0.3,0,1,0,0.05,0.05])
n = len(w0)
constraints = ( {'type':'eq', 'fun': restriccion} )
bounds = [(0,1) for _ in range(n)]
result = sp.minimize(Cost,w0,method='SLSQP',bounds=bounds,constraints=constraints)
result
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -5358.693582655122
#        x: [ 4.511e-13  2.629e-13  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00  1.000e+00]
#      nit: 3
#      jac: [-1.749e+03 -1.799e+03 -1.770e+03 -1.927e+03 -2.060e+03
#            -2.266e+03 -2.592e+03]
#     nfev: 35
#     njev: 3

# %%
AIC = result.fun

# %%
print(AIC)
np.round(result.x,2)
# Out:
# -5358.693582655122
# array([0., 0., 0., 0., 0., 0., 1.])

# %%
wopt = result.x

# %%
meanopt = GetMediaMovilPonderada(x,wopt)

# %%
plt.plot(x)
plt.plot(media,label='media movil standard')
plt.plot(Wmedia,label='media movil ponderada')
plt.plot(meanopt,label='media movil ponderada optimizada')
plt.legend()

# %%
plt.hist( meanopt[-1] - x )
# Out:
# (array([ 46., 142., 159., 145.,  84.,  97., 112.,  21.,  83.,  33.]),
#  array([-1.18764 , -0.944766, -0.701892, -0.459018, -0.216144,  0.02673 ,
#          0.269604,  0.512478,  0.755352,  0.998226,  1.2411  ]),
#  <BarContainer object of 10 artists>)

# %%
def OptimizarModelo():

  AIC = []
  kday = []
  wopt = []

  for n in range(2,8):

    w0 = np.ones(n)
    w0 = w0/n

    constraints = ( {'type':'eq', 'fun': restriccion} )
    bounds = [(0,1) for _ in range(n)]
    result = sp.minimize(Cost,w0,bounds=bounds,constraints=constraints)
    print( 'optimal:', result.x)

    AIC.append(result.fun)
    kday.append(n)
    wopt.append(result.x)

  return kday,AIC,wopt

# %%
kday,AIC,wopt = OptimizarModelo()
# Out:
# optimal: [0.40388644 0.59611356]
# optimal: [0.20787942 0.27806723 0.51405334]
# optimal: [0.11233948 0.1519287  0.24426457 0.49146724]
# optimal: [0.11618312 0.05637099 0.12408927 0.22428166 0.47907495]
# optimal: [0.0618058  0.08846006 0.04133183 0.1157039  0.22063764 0.47206076]
# optimal: [0.02100579 0.05625545 0.07774992 0.0407333  0.11235939 0.22101041
#  0.47088573]

# %%
plt.plot(kday,AIC)

# %%
wopt
# Out:
# [array([0.40388644, 0.59611356]),
#  array([0.20787942, 0.27806723, 0.51405334]),
#  array([0.11233948, 0.1519287 , 0.24426457, 0.49146724]),
#  array([0.11618312, 0.05637099, 0.12408927, 0.22428166, 0.47907495]),
#  array([0.0618058 , 0.08846006, 0.04133183, 0.1157039 , 0.22063764,
#         0.47206076]),
#  array([0.02100579, 0.05625545, 0.07774992, 0.0407333 , 0.11235939,
#         0.22101041, 0.47088573])]

# %%
wopt[1]
# Out:
# array([0.20787942, 0.27806723, 0.51405334])
