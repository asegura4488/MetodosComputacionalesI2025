# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana151/HiddenMarkovModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import permutations
from itertools import combinations
from itertools import combinations_with_replacement

# %%
# Definimos estados y priors
States = np.array([0,1])
Prior = np.array([0.4,0.6])

# %%
# Definimos matrices de emisión y transmision
T = np.array([[0.7,0.5],[0.3,0.5]])

E = np.array([[0.8,0.2],[0.1,0.3],[0.1,0.5]])

#np.sum(T,axis=0)

# %%
# Secuencia Observad
Obs = np.array([1,2,0])

# %%
DictH = {0:'Feliz',1:'Triste'}
DictH[0]
# Out:
# 'Feliz'

# %%
DictO = {0:'Rojo',1:'Verde',2:'Azul'}
DictO[0]
# Out:
# 'Rojo'

# %%
def GetStates(State,N):

  CStates = list(combinations_with_replacement(States,N))
  #print(CStates)
  #print(len(CStates))
  Permu = []

  for it in CStates:
    p = list(permutations(it,N))

    for i in p:
      if i not in Permu:
        Permu.append(i)
  return Permu

# %%
HiddenStates = GetStates(States,3)
HiddenStates
# Out:
# [(np.int64(0), np.int64(0), np.int64(0)),
#  (np.int64(0), np.int64(0), np.int64(1)),
#  (np.int64(0), np.int64(1), np.int64(0)),
#  (np.int64(1), np.int64(0), np.int64(0)),
#  (np.int64(0), np.int64(1), np.int64(1)),
#  (np.int64(1), np.int64(0), np.int64(1)),
#  (np.int64(1), np.int64(1), np.int64(0)),
#  (np.int64(1), np.int64(1), np.int64(1))]

# %%
def GetProb(T,E,Obs,State,Prior):

  n = len(Obs)
  p = 1.

  # Probabilidad a priori

  p = Prior[ State[0] ]
  print(p)
  for i in range(n-1):
    p *= T[ State[i+1],State[i] ]
  #  print(p)

  for i in range(n):
    p *= E[ Obs[i],State[i] ]
   # print(p)

  return p

# %%
GetProb(T,E,Obs,[0,0,1],Prior)
# Out:
# 0.4
# np.float64(0.00016800000000000002)

# %%
0.4*0.7*0.3
# Out:
# 0.08399999999999999
