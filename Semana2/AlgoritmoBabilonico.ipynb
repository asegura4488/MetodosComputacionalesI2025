# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionalesI2025/blob/main/Semana2/AlgoritmoBabilonico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython.display import clear_output
from decimal import Decimal, getcontext
#%matplotlib inline

# %%
getcontext().prec = 100

# %%
Decimal(2.)
# Out:
# Decimal('2')
